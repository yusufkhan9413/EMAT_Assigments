# %% [markdown]
# Matplotlib Challenge
#
# Yusuf Khan 811286910

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # HeatMap
#
# They help identify trends, patterns, and anomalies within data, such as correlations between different metrics or the frequency of events.
#
# **Interpretation of Correlation Heatmaps:**
#
# **Positive Correlation**: This indicates that as one variable increases and the other also increases. Shown in warmer colors (reds or oranges).
#
# **Negative Correlation**: This indicates that as one variable increases, the other decreases. Shown in cooler colors (blue).
#
# **Weak or No Correlation**: This indicates no strong linear relationship between the variables. These are the correlations close to zero and shown in neutral colors (like white or light yellow)
#
# Examples of usage of Heatmap: Insurance, Finance, Healthcare, Supply Chain, Prediction.hain

# %%
# Loading the CSV file into a DataFrame

df = pd.read_csv('cces_example_data.csv')

# Display the first row of the DataFrame to confirm successful loading
df.head(1)
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1          1.0  ...              -99             -99            -96
#
#    LibMediaUse  ConMediaUse  Real_Threat  Symb_Threat  Evaluation  teamweight  \
# 0     2.666667          1.0          5.0     4.857143           0    0.505028
#
#        caseid
# 0  1231308943
#
# [1 rows x 21 columns]

# %%
# Createing a figure with two axes arranged in a matrix (1 row, 2 columns)
fig0, axes0 = plt.subplots(1, 2, figsize=(8, 4))    #figsize(a, b) a is the horzontal size and b is vertical size of the figure

# Set the title for the first axes
axes0[0].set_title("Age Histogram")

# Set the title for the second axes
axes0[1].set_title("Political Identity")

# Display the figure
plt.show()

# %%
#describing the content of the file

df.describe()
# Out:
#        pew_religimp  pew_churatd         sex        educ    nonwhite  \
# count    659.000000   659.000000  659.000000  659.000000  659.000000
# mean       2.342944     4.294385    1.559939    3.813354    1.254932
# std        1.192998     1.725409    0.496771    1.471121    0.436154
# min        1.000000     1.000000    1.000000    1.000000    1.000000
# 25%        1.000000     3.000000    1.000000    2.000000    1.000000
# 50%        2.000000     5.000000    2.000000    4.000000    1.000000
# 75%        4.000000     6.000000    2.000000    5.000000    2.000000
# max        4.000000     7.000000    2.000000    6.000000    2.000000
#
#               age  faminc_new        pid3       ideo5  QueerPhobia  ...  \
# count  659.000000  659.000000  659.000000  659.000000   659.000000  ...
# mean    52.180577   15.908953    1.977238    3.083460     2.600910  ...
# std     16.842264   27.724506    0.860002    1.282575     1.163468  ...
# ...

# %%
#showing all the columns of the file

df.keys()
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
# I chose to use the groupby method based on the Real_Threat column
evaluation_freq = df.groupby('Evaluation')['Real_Threat'].count()
evaluation_freq       #will show us the frequency of evaluatgion with index
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# Name: Real_Threat, dtype: int64

# %%
evaluation_freq.index
# Out:
# Index([0, 1, 2, 3], dtype='int64', name='Evaluation')

# %%
#Ceating the bar chart for the evaluation column
                               
fig1, axes1 = plt.subplots(figsize = (8, 5))
axes1.bar(x= evaluation_freq.index, height = evaluation_freq, color='skyblue')
axes1.set_title('Evaluation of Real Threats')

# Display the figure
plt.show()

# %%
#creating a scatter plot 
fig2,axes2 = plt.subplots()
axes2.scatter(x=df['ConMediaUse'], y=df['ImmiPhobia'], color='lightblue', marker='o')
#adding labels and a title 
axes2.set_xlabel('ConMediaUse')
axes2.set_ylabel('ImmiPhobia')
axes2.set_title('Scatter Plot of ConMediaUse vs. ImmiPhobia')
plt.show()

# %% [markdown]
# # Ways to improve the scatter pots:
#
# **Partial Transperancy**: One way to overlapping point problem is to use partial transparency. If we make individual points partially transparent, then overplotted points appear as darker points and thus the shade of the points reflects the density of points in that location of the graph.
#
# **Jittering**: A simple trick that can further helps is to apply a small amount of jitter to the points, i.e., to displace each point randomly by a small amount in either the x or the y direction or both. With jitter, it is immediately apparent that the darker areas arise from points that are plotted on top of each other
#
# **Interactive Scatter Plots**: For larger or more complex datasets, turning the scatterplot into an interactive visualization can greatly enhance usability. Viewers can hover over individual points to see specific values, filter data dynamically, or zoom in on areas of interest.
#
# **Aesthetics**: Aesthetics describe every aspect of a given graphical element such as a shape, a size, and a color. We can add different shapes and colors for different variables.
#
#
# **Downside of Jittering**: One downside of jittering is that it does change the data and therefore has to be performed with care. If we jitter too much, we end up placing points in locations that are not representative of the underlying dataset. The result is a misleading visualization of the data.
#
#
# Refrences:
#
# https://clauswilke.com/dataviz/aesthetic-mapping.html
# https://clauswilke.com/dataviz/overlapping-points.html
# https://clauswilke.com/dataviz/directory-of-visualizations.html
